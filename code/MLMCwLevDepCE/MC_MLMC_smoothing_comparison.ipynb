time_vec_lev_dep = np.array([0.02844071388244629, 0.04794552326202393, 0.09589104652404785, 0.37462828159332273, 2.219128584861755, 5.291034626960755, 10.872991371154786, 106.63571813106537, 920.3155652284622, 2446.3585921525955, 5550.6090404987335])

relative_rmse_mc = rmse_vec_mc/0.6371412034403666
relative_rmse_mlmc = rmse_vec_mlmc/0.6371412034403666
relative_rmse_lev_dep = rmse_vec_lev_dep/0.6371412034403666

# %%
# rho = 0.03, nu = 1.5 for point evaluation
rmse_vec_mc = np.array([0.06891542442704095, 0.03567124821040427, 0.021446740425371785, 0.009116969756886312, 0.007465808524005612, 0.00596641305679617])
time_vec_mc = np.array([0.046543121337890625, 0.26619863510131836, 0.9406242370605469, 22.358135461807251, 52.40931153297424, 479.1142728328705])

rmse_vec_mlmc = np.array([0.06637985442252881, 0.04637985442252881, 0.03642671811483972, 0.032437284484663646, 0.018074859239469353, 0.009018866866443011, 0.006663345952532919, 0.004292614093084413, 0.0021771031213350103, 0.001472141957838984])
time_vec_mlmc = np.array([0.24462793827056887, 0.28462793827056887, 0.32980272769927976, 0.3749775171279907, 1.260456919670105, 7.607916307449341, 24.668240427970886, 80.42555069923401, 417.35008945465086, 1958.7063294172287])

rmse_vec_lev_dep = np.array([0.0595523690585636, 0.05275357644132725, 0.03629284273480284, 0.021841690302123015, 0.00678793592911106, 0.005494513811020463, 0.0038304093394893497, 0.0023366595666228602, 0.0009358325939214197])
time_vec_lev_dep = np.array([0.06004948616027832, 0.07628829479217529, 0.1717754602432251, 0.6432911634445191, 12.152487564086913, 29.768304085731508, 67.24494903087616, 265.98350343704226, 5540.437187361717])

relative_rmse_mc = rmse_vec_mc/0.630611468922694
relative_rmse_mlmc = rmse_vec_mlmc/0.630611468922694
relative_rmse_lev_dep = rmse_vec_lev_dep/0.630611468922694

# %%
# rho = 0.03, nu = 1.5 for L2 norm
rmse_vec_mc = np.array([0.05737401021905612, 0.020999251006402446, 0.009657492453182348, 0.006149984960348333, 0.004692410272001797, 0.00293888512215138])
time_vec_mc = np.array([0.02187323570251465, 0.26548218727111816, 4.940886735916138, 28.206012725830078, 90.35898113250732, 1340.9870641231537])

rmse_vec_mlmc = np.array([0.053097714302628313, 0.023097714302628313, 0.015712748287223167, 0.007484814109425654, 0.005946971492396499, 0.004552878861663974, 0.0018168823316187658, 0.0009383627018201585, 0.0008219914185719052])
time_vec_mlmc = np.array([0.18462793827056887, 0.28462793827056887, 0.3749775171279907, 1.7709588050842284, 3.121765303611755, 6.7992072820663445, 84.47114748954773, 485.88741490840914, 844.8779828071595])

rmse_vec_lev_dep = np.array([0.044844358445217364, 0.030403687967009672, 0.018840552624996922, 0.009234187691245446, 0.005791666707458859, 0.0042669393494536335, 0.0023835194327341326, 0.0010011355708486225, 0.000889893390035726])
time_vec_lev_dep = np.array([0.03002474308013916, 0.06546242237091064, 0.18801426887512207, 0.9403469562530518, 2.913500905036926, 6.213830494880675, 22.23217368125916, 250.0444408655167, 412.6519669532777])

relative_rmse_mc = rmse_vec_mc/0.635118713378675
relative_rmse_mlmc = rmse_vec_mlmc/0.635118713378675
relative_rmse_lev_dep = rmse_vec_lev_dep/0.635118713378675

# %%
# plotting MLMC with and without smoothing
plt.figure(1, figsize=(10,8))
# use log-log scale
plt.loglog(rmse_vec_lev_dep, time_vec_lev_dep, 'k-x', label = "RMSE lev dep KL exp")
plt.loglog(rmse_vec_mlmc, time_vec_mlmc, 'r-x', label = "RMSE MLMC")

plt.title(r'CPU times for computing $\hat{Q}$ using uniform and LD KL-expansion', fontsize=14)
plt.xlabel('RMSE', fontsize=14)
plt.ylabel('CPU time', fontsize=14)
plt.grid(linestyle='--', linewidth=0.5)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.legend()
plt.show()

# %%
# plotting relative error MLMC with and without smoothing
plt.figure(1, figsize=(10,8))
# use log-log scale
plt.loglog(relative_rmse_lev_dep, time_vec_lev_dep, 'k-x', label = "RMSE lev dep KL exp")
plt.loglog(relative_rmse_mlmc, time_vec_mlmc, 'r-x', label = "RMSE MLMC")

plt.title(r'CPU times for computing $\hat{Q}$ using uniform and LD KL-expansion', fontsize=14)
plt.xlabel('RMSE', fontsize=14)
plt.ylabel('CPU time', fontsize=14)
plt.grid(linestyle='--', linewidth=0.5)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.legend()
plt.show()

# %%
# plotting MC vs MLMC with and without smoothing
plt.figure(2, figsize=(15,8))

# use log-log scale
slope, interc = \
    np.polyfit(x=np.log(rmse_vec_mc[:]), y=np.log(time_vec_mc[:]), deg=1)
plt.loglog(rmse_vec_mc, time_vec_mc, 'c-s', label = rf'$\varepsilon$^{round(slope,2)} RMSE MC')

slope, interc = \
    np.polyfit(x=np.log(rmse_vec_mlmc[2:]), y=np.log(time_vec_mlmc[2:]), deg=1)
print(np.exp(interc))
plt.loglog(rmse_vec_mlmc, time_vec_mlmc, 'r-v', label = rf'$\varepsilon$^{round(slope,2)} RMSE MLMC')

slope, interc = \
    np.polyfit(x=np.log(rmse_vec_lev_dep[:]), y=np.log(time_vec_lev_dep[:]), deg=1)
print(np.exp(interc))
plt.loglog(rmse_vec_lev_dep, time_vec_lev_dep, 'k-o', label = rf'$\varepsilon$^{round(slope,2)} RMSE smoothing')

# plt.title(r'Time complexity for $p(\mathbf{x}^*)$ with $\rho=0.03$ and $\nu=1.5$', fontsize=20)
# plt.title(r'Time complexity for $||u(\cdot, \omega)||_{L_2(D)}$ with $\lambda=0.03$ and $\nu=1.5$', fontsize=20)
plt.title(r'Time complexity for $u(\mathbf{x}^*)$ with $\lambda=0.1$', fontsize=20)
# plt.title(r'Time complexity for $||p||_{L_2(D)}$ with $\rho=0.1$', fontsize=20)
plt.xlabel('relative RMSE', fontsize=20)
plt.ylabel('CPU time', fontsize=20)
plt.grid(linestyle='--', linewidth=0.5)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.legend(fontsize=16)
plt.show()
# Out:
# 0.0001583288180883317
# 6.543349439808116e-05
